# %%
import matplotlib.pyplot as plt
import numpy as np

SL, SH, ULL, ULH, ULmL, ULmH, DL, DH = [], [], [], [], [], [], [], []

TL1, TH1 = [0.1, 0.05, 0.01], [0.1, 0.05, 0.01]
TL2, TH2 = [0.1, 0.2, 0.3, 0.4], [0.05, 0.1, 0.2, 0.3]
SL1, SH1, ULL1, ULH1, ULmL1, ULmH1, DL1, DH1 = [], [], [], [], [], [], [], []
SL2, SH2, ULL2, ULH2, ULmL2, ULmH2, DL2, DH2 = [], [], [], [], [], [], [], []

# %% [markdown]
# # Low Energy, LST data

# %%
SL.append(0.15); SL.append(0.63); SL.append(0.31); SL.append(0.65)
ULL.append(4.911e-11); ULL.append(3.104e-11); ULL.append(2.961e-11); ULL.append(3.310e-11)
ULmL.append(4.974e-11); ULmL.append(3.202e-11); ULmL.append(2.823e-11); ULmL.append(3.255e-11)
DL.append(-1.3); DL.append(-3.1); DL.append(4.9); DL.append(1.7)

# %%
SL.append(0.09); SL.append(-3.25); SL.append(-2.42); SL.append(-1.73)
ULL.append(2.315e-11); ULL.append(2.315e-11); ULL.append(2.410e-11); ULL.append(2.410e-11)
ULmL.append(2.434e-11); ULmL.append(2.258e-11); ULmL.append(2.263e-11); ULmL.append(2.256e-11)
DL.append(-4.9); DL.append(2.5); DL.append(6.5); DL.append(6.9)

# %%
SL.append(-2.61); SL.append(-2.11); SL.append(-0.02); SL.append(-1.55)
ULL.append(2.410e-11); ULL.append(2.284e-11); ULL.append(2.284e-11); ULL.append(2.284e-11)
ULmL.append(2.251e-11); ULmL.append(2.265e-11); ULmL.append(2.263e-11); ULmL.append(2.255e-11)
DL.append(7.1); DL.append(0.8); DL.append(0.9); DL.append(1.3)

# %%
SL.append(-1.66); SL.append(-2.53)
ULL.append(2.253e-11); ULL.append(2.253e-11)
ULmL.append(2.273e-11); ULmL.append(2.252e-11)
DL.append(-0.9); DL.append(0.1)

# %%
# different pixel size, same position center cont = 0.3

# %%
# 0.1
SL.append(-3.05); SL1.append(-3.05)
ULL.append(2.315e-11); ULL1.append(2.315e-11)
ULmL.append(2.259e-11); ULmL1.append(2.259e-11)
DL.append(2.5); DL1.append(2.5)

# %%
# 0.05
SL.append(-2.15); SL1.append(-2.15)
ULL.append(2.253e-11); ULL1.append(2.253e-11)
ULmL.append(2.173e-11); ULmL1.append(2.173e-11)
DL.append(3.7); DL1.append(3.7)

# %%
# 0.01
SL.append(-2.59); SL1.append(-2.59)
ULL.append(1.982e-11); ULL1.append(1.982e-11)
ULmL.append(2.171e-11); ULmL1.append(2.171e-11)
DL.append(-8.7); DL1.append(-8.7)

# %%
# different containment, same psoition center psize = 0.05

# %%
Analysis of mono data in Energies 0.15 TeV-0.60 TeV

Significance of observations: -0.52σ

Sensitivity:  phi0=5.05e-12  Flux=2.53e-11 1 / (s cm2)  dFlux=1.12e-11 erg / (s cm2)
Upper Limit:  phi0=5.05e-12  Flux=2.53e-11 1 / (s cm2)  dFlux=1.12e-11 erg / (s cm2)

UL vs sky-map 95% max: 2.527e-11 vs 2.620e-11  (-3.6%)

# %%
# 0.1
SL.append(-0.58); SL2.append(-0.58)
ULL.append(2.050e-11); ULL2.append(2.050e-11)
ULmL.append(2.063e-11); ULmL2.append(2.063e-11)
DL.append(-0.6); DL2.append(-0.6)

# %%
# 0.2
SL.append(-2.53); SL2.append(-2.53)
ULL.append(1.969e-11); ULL2.append(1.969e-11)
ULmL.append(1.917e-11); ULmL2.append(1.917e-11)
DL.append(2.7); DL2.append(2.7)

# %%
# 0.3
SL.append(-2.15); SL2.append(-2.15)
ULL.append(2.253e-11); ULL2.append(2.253e-11)
ULmL.append(2.172e-11); ULmL2.append(2.172e-11)
DL.append(3.7); DL2.append(3.7)

# %%
# 0.4
SL.append(-1.95); SL2.append(-1.95)
ULL.append(2.596e-11); ULL2.append(2.596e-11)
ULmL.append(2.545e-11); ULmL2.append(2.545e-11)
DL.append(2.0); DL2.append(2.0)

# %% [markdown]
# # High-Energy, Stereo

# %%
# Now HE
SH.append(0.86); SH.append(-0.68); SH.append(-2.09); SH.append(0.24)
ULH.append(2.385e-12); ULH.append(1.922e-12); ULH.append(1.877e-12); ULH.append(1.674e-12)
ULmH.append(2.089e-12); ULmH.append(1.754e-12); ULmH.append(1.362e-12); ULmH.append(1.519e-12)
DH.append(14.2); DH.append(9.6); DH.append(37.8); DH.append(10.2)

# %%
SH.append(-0.02); SH.append(0.11); SH.append(0.02); SH.append(-0.85)
ULH.append(1.586e-12); ULH.append(1.367e-12); ULH.append(1.304e-12); ULH.append(1.395e-12)
ULmH.append(1.222e-12); ULmH.append(1.332e-12); ULmH.append(1.251e-12); ULmH.append(1.226e-12)
DH.append(29.8); DH.append(2.6); DH.append(4.3); DH.append(13.8)

SH.append(1.20); SH.append(1.01); SH.append(-0.72)
ULH.append(2.426e-12); ULH.append(2.410e-12); ULH.append(1.433e-12)
ULmH.append(2.155e-12); ULmH.append(2.014e-12); ULmH.append(1.220e-12)
DH.append(12.6); DH.append(19.6); DH.append(17.5)

# %%
# different pixel size, same position center cont = 0.1

# %%
# 0.1
SH.append(0.02); SH1.append(0.02)
ULH.append(1.295e-12); ULH1.append(1.295e-12)
ULmH.append(1.223e-12); ULmH1.append(1.223e-12)
DH.append(6.0); DH1.append(6.0)

# %%
# 0.05
SH.append(0.09); SH1.append(0.09)
ULH.append(1.179e-12); ULH1.append(1.179e-12)
ULmH.append(1.181e-12); ULmH1.append(1.181e-12)
DH.append(-0.2); DH1.append(-0.2)

# %%
# 0.01
SH.append(0.09); SH1.append(0.09)
ULH.append(1.156e-12); ULH1.append(1.156e-12)
ULmH.append(1.062e-12); ULmH1.append(1.062e-12)
DH.append(8.8); DH1.append(8.8)

# %%
# different containment, same psoition center psize = 0.05

# %%
SH.append(0.15); SH2.append(0.15)
ULH.append(1.779e-12); ULH2.append(1.779e-12)
ULmH.append(1.550e-12); ULmH2.append(1.550e-12)
DH.append(14.8); DH2.append(-1.9)

Significance of observations: 0.15σ

Sensitivity:  phi0=1.10e-12  Flux=1.78e-12 1 / (s cm2)  dFlux=6.18e-12 erg / (s cm2)
Upper Limit:  phi0=1.10e-12  Flux=1.78e-12 1 / (s cm2)  dFlux=6.18e-12 erg / (s cm2)

UL vs sky-map 95% max: 1.779e-12 vs 1.550e-12  (+14.8%)

# %%
# 0.05
SH.append(0.59); SH2.append(0.59)
ULH.append(1.493e-12); ULH2.append(1.493e-12)
ULmH.append(1.522e-12); ULmH2.append(1.522e-12)
DH.append(-1.9); DH2.append(-1.9)

# %%
# 0.1
SH.append(0.09); SH2.append(0.09)
ULH.append(1.179e-12); ULH2.append(1.179e-12)
ULmH.append(1.180e-12); ULmH2.append(1.180e-12)
DH.append(-0.1); DH2.append(-0.1)

# %%
# 0.2
SH.append(-0.07); SH2.append(-0.07)
ULH.append(1.575e-12); ULH2.append(1.575e-12)
ULmH.append(1.550e-12); ULmH2.append(1.550e-12)
DH.append(1.7); DH2.append(1.7)

# %%
# 0.3
SH.append(0.63); SH2.append(0.63)
ULH.append(3.051e-12); ULH2.append(3.051e-12)
ULmH.append(3.005e-12); ULmH2.append(3.005e-12)
DH.append(1.5); DH2.append(1.5)

# %%
SL, SH = np.array(SL), np.array(SH)
ULL, ULH = np.array(ULL), np.array(ULH)
ULmL, ULmH = np.array(ULmL), np.array(ULmH)
DL, DH = np.array(DL), np.array(DH)
SL1, SH1 = np.array(SL1), np.array(SH1)
ULL1, ULH1 = np.array(ULL1), np.array(ULH1)
ULmL1, ULmH1 = np.array(ULmL1), np.array(ULmH1)
DL1, DH1 = np.array(DL1), np.array(DH1)
SL2, SH2 = np.array(SL2), np.array(SH2)
ULL2, ULH2 = np.array(ULL2), np.array(ULH2)
ULmL2, ULmH2 = np.array(ULmL2), np.array(ULmH2)
DL2, DH2 = np.array(DL2), np.array(DH2)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(6, 6), sharex=True)
ax1.axhline(0, ls="--", color="lightgray")
ax1.plot(SL, DL, "bx", label="LE (mono)")
ax1.plot(SH, DH, "rx", label="HE (stereo)")

ax2.errorbar(SL, ULL*1e11, yerr=0.05, color="r", ls="", marker=".", uplims=True, label="Frequentist")
ax2.errorbar(SL, ULmL*1e11, yerr=0.05, color="k", ls="", marker=".", uplims=True, label="Gammapy")

ax3.errorbar(SH, ULH*1e12, yerr=0.05, color="r", ls="", marker=".", uplims=True, label="Frequentist")
ax3.errorbar(SH, ULmH*1e12, yerr=0.05, color="k", ls="", marker=".", uplims=True, label="Gammapy")

ax1.set(ylabel="Diff [%]")
ax2.set(ylabel="Flux UL [1e-11 cm-2 s]\n0.15-0.6 TeV")
ax3.set(xlabel="Significance [$\\sigma$]", ylabel="Flux UL [1e-12 cm-2 s]\n0.6-20 TeV")
for ax in [ax1, ax2, ax3]:
    ax.legend(frameon=False, loc=(1, 0))
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7,5.5))

ax1.plot(TL1, DL1, "bo-", label="LE (mono)")
ax1.plot(TH1, DH1, "ro-", label="HE (stereo)")

ax2.plot(TL2, DL2, "bo-", label="LE (mono)")
ax2.plot(TH2, DH2, "ro-", label="HE (stereo)")

ax1.set(xlabel="Pixel size [deg]", ylabel="Diff [%]", title="Pixel size test")
ax2.set(xlabel="Cont Rad [deg]", ylabel="Diff [%]", title="Containment radius test")

for ax in [ax1, ax2]:
    ax.legend(frameon=False, loc=(1, 0))
fig.tight_layout()    
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7,5.5))

ax1.errorbar(TL1, ULL1*1e11, yerr=0.03, color="r", marker="o", ls="--", label="Frequentist", uplims=True)
ax1.errorbar(TL1, ULmL1*1e11, yerr=0.03, color="k", marker="o", ls="--", label="Gammapy", uplims=True)

ax2.errorbar(TH1, ULH1*1e12, yerr=0.03, color="r", marker="o", ls="--", label="Frequentist", uplims=True)
ax2.errorbar(TH1, ULmH1*1e12, yerr=0.03, color="k", marker="o", ls="--", label="Gammapy", uplims=True)


ax1.set(xlabel="Pixel size [deg]", ylabel="Flux UL [cm-2 s]\n0.15-0.6 TeV", title="Pixel size test")
ax2.set(xlabel="Pixel size [deg]", ylabel="Flux UL [cm-2 s]\n0.6-20 TeV")

for ax in [ax1, ax2]:
    ax.legend(frameon=False, loc=(1, 0))
plt.subplots_adjust(wspace=0, hspace=0)  
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7,5.5))

ax1.errorbar(TL2, ULL2*1e11, yerr=0.03, color="r", marker="o", ls="--", label="Frequentist", uplims=True)
ax1.errorbar(TL2, ULmL2*1e11, yerr=0.03, color="k", marker="o", ls="--", label="Gammapy", uplims=True)

ax2.errorbar(TH2, ULH2*1e12, yerr=0.1, color="r", marker="o", ls="--", label="Frequentist", uplims=True)
ax2.errorbar(TH2, ULmH2*1e12, yerr=0.1, color="k", marker="o", ls="--", label="Gammapy", uplims=True)


ax1.set(ylabel="Flux UL [cm-2 s]\n0.15-0.6 TeV", title="Containment radius test")
ax2.set(xlabel="Cont Rad [deg]", ylabel="Flux UL [cm-2 s]\n0.6-20 TeV")

for ax in [ax1, ax2]:
    ax.legend(frameon=False, loc=(1, 0))
fig.tight_layout()    
plt.show()
