# %% [markdown]
# ### Import packages

# %%
import os, subprocess, pickle, warnings, logging, copy
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import healpy as hp

from matplotlib.colors import LogNorm
from matplotlib.gridspec import GridSpec
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation
from scipy.stats import norm
from scipy.optimize import curve_fit, root_scalar
from scipy.ndimage import gaussian_filter

# --- Gammapy ---
from gammapy import __version__ as gammapy_version
from gammapy.irf import load_irf_dict_from_file
from gammapy.maps import MapAxis, WcsGeom, Map
from gammapy.modeling.models import PointSpatialModel, PowerLawSpectralModel, ConstantTemporalModel, SkyModel, Models
from gammapy.data import DataStore, Observation, FixedPointingInfo, PointingMode
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker
from gammapy.datasets import Dataset, Datasets, MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, TSMapEstimator
from gammapy.stats.fit_statistics import cash
from gammapy.estimators.map.excess import convolved_map_dataset_counts_statistics, _get_convolved_maps
observing_location = EarthLocation.of_site("Roque de los Muchachos")

# --- Configurations ---
warnings.filterwarnings("ignore", category=RuntimeWarning, append=True)
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
warnings.filterwarnings("ignore", message=".*outside valid IRF map range.*")
logging.getLogger("gammapy").setLevel(logging.ERROR)

# --- External & Local Utils ---
import ligo.skymap.plot
from ligo.skymap.io.fits import read_sky_map
import utils

# We create the needed paths
for path in ["./data/", "./data/tmp/", "./data/gw_input/", "./data/results/", "./data/slurm_output/"]:
    os.makedirs(path, exist_ok=True)

from gammapy import __version__ as gammapy_version
from gammapy import __path__ as gammapy_path
print(f"Using Gammapy version: {gammapy_version}\nIn path: {gammapy_path[0]}")
# Out:
# Using Gammapy version: 2.0.1
# In path: /fefs/aswg/workspace/juan.jimenez/softs/conda/envs/gammapy-dev/lib/python3.13/site-packages/gammapy

# %% [markdown]
# ##### <span style="color:blue">Main parameters</span>
# * `source_name` Source name
# * `dir_dl3` DL3 directory
# * `e_min`, `e_max` and `e_bins`: Maximum, minimum energies and bins per decade
# * `obs_id`: The run numbers to be used
# * `bkg_type` If you want to use `baccmod` or `pybkgmodel`
# * `e_min`, `e_max` and `e_bins`: Maximum, minimum offset, and total bins

# %%
# source_name = "S240615dg"
# source_coord = SkyCoord(ra=7.53, dec=45.81, unit="deg")

# dir_dl3 = os.path.join(
#     "/fefs/aswg/workspace/juan.jimenez/data/real", "mono", source_name, "v0.11.4", 
#     "GammaDiffuse", "prod_standard", "DL3", "gh_dyn70"
# )
# obs_ids = [17822, 17823, 17824, 17825]

# # Tool used for background computation
# bkg_type = "baccmod" # baccmod or pybkgmodel

# # Binning: energy and offset
# e_min, e_max, e_bins = 0.15 * u.TeV, 0.6 * u.TeV, 4.5
# o_min, o_max, o_bins = 0 * u.deg, 2.5 * u.deg, 5 # Offset binning
# correlation_radius = 0.25 * u.deg

# %%
source_name = "S240615dg"
source_coord = SkyCoord(ra=7.53, dec=45.81, unit="deg")

dir_dl3 = os.path.join(
    "/fefs/aswg/workspace/juan.jimenez/data/real", "stereo", source_name, "v0.6.1", 
    "GammaDiffuse", "prod_standard", "DL3", "gh_dyn90"
)

obs_ids = [17821, 17822, 17823, 17824, 17825]

# Tool used for background computation
bkg_type = "pybkgmodel" # baccmod or pybkgmodel

# Binning: energy and offset
e_min, e_max, e_bins = 0.6 * u.TeV, 20 * u.TeV, 4.5
o_min, o_max, o_bins = 0 * u.deg, 2.5 * u.deg, 8 # Offset binning
correlation_radius = 0.1 * u.deg

# %% [markdown]
# Other secundary parameters

# %%
# Confidence level for SkyMap results
confidence_level = 0.95

# --- Binning --- #
size_fov = 2.5 * u.deg

# For the ring-wobble method geometry used
ring_r_in, ring_width = 0.3 * u.deg, 0.2 * u.deg

resolution_hp_to_grid = 2048 # Resolution of the HEALPix map to be used
threshold_percent_gw = np.flip(np.sort([0.95, 0.5])) # % of probabilities contours

# Geometry parameters --- 
geom_width = size_fov.value * 1.43, size_fov.value * 1.43
binsz = 0.02

# True energy geometry (needs to be larger than the reco energy geom)
e_t_min, e_t_max, e_t_bins = 0.05 * u.TeV, 100 * u.TeV, 6

# %% [markdown]
# ### <span style="color:blue">Reading GW data</span>

# %%
# %%time
file_ligo = f"./data/gw_input/{source_name}.fits"

# Extracting coordinates from healpy
ra_bins  = np.linspace(-180, 180, resolution_hp_to_grid)
dec_bins = np.linspace(-90, 90, resolution_hp_to_grid)
ra_grid, dec_grid = np.deg2rad(np.meshgrid(ra_bins, dec_bins))

# Reading GW data
data_ligo_hp, meta_ligo_hp = read_sky_map(file_ligo)
data_ligo_2d = utils.healpix2map(data_ligo_hp, ra_bins, dec_bins)
data_ligo_2d_smooth = gaussian_filter(data_ligo_2d, sigma=2)

# Getting the thresholds for probability containment
threshold_maps = utils.get_hp_map_thresholds(data_ligo_hp, threshold_percent_gw)

# Getting the coordinate of hottest spot
hotspot_coord = utils.get_2d_map_hotspot(data_ligo_2d, ra_bins, dec_bins)
# Out:
# CPU times: user 21.5 s, sys: 13.9 s, total: 35.4 s
# Wall time: 35.4 s

# %% [markdown]
# ### Defining the geometry (FoV, Energy axis, Spatial Binning)

# %%
# Defining offset axis
axis_offset = MapAxis.from_bounds(o_min, o_max, nbin=o_bins, name="offset")
# Defining energy axis
axis_energy = MapAxis.from_energy_bounds(
    e_min, e_max, nbin=e_bins, per_decade=True, name="energy"
)
axis_energy_true = MapAxis.from_energy_bounds(
    e_t_min, e_t_max, nbin=e_bins, per_decade=True, name="energy_true"
)
print(f"Energy axis edges:"); display(axis_energy.edges)
print(f"\nOffset axis edges:"); display(axis_offset.edges)

npix = (int(geom_width[0]/binsz), int(geom_width[1]/binsz))
geom = WcsGeom.create(
    skydir=(source_coord.ra.degree, source_coord.dec.degree), 
    npix=npix, binsz=binsz, width=geom_width, frame="icrs", proj="AIR", axes=[axis_energy],
)
geom_image = geom.to_image()

# Extracting coords of geom
geom_centers = geom.get_coord(mode="center")
geom_edges = geom.get_coord(mode="edges")
bin_c_ra, bin_c_dec = geom_centers.lon[0].value, geom_centers.lat[0].value
bin_edges_ra, bin_edges_dec = geom_edges.lon[0].value, geom_edges.lat[0].value
bin_area = geom_image.solid_angle()
coord_array = SkyCoord(bin_c_ra, bin_c_dec, unit=u.deg)
coord_center = coord_array[(coord_array.shape[0])//2,(coord_array.shape[0])//2]

separations_map = coord_array.separation(SkyCoord(*geom.center_coord)).deg

# Plotting geometry summary
utils.summary_geometry(geom, bin_edges_ra, bin_edges_dec, size_fov, data_ligo_2d, threshold_maps)
# Out:
# Energy axis edges:
# <Quantity [ 0.6       ,  0.99015995,  1.63402788,  2.69658162,  4.45007854,
#             7.34381593, 12.11925404, 20.        ] TeV>
# Offset axis edges:
# <Quantity [0.    , 0.3125, 0.625 , 0.9375, 1.25  , 1.5625, 1.875 , 2.1875,
#            2.5   ] deg>

# %% [markdown]
# ### <span style="color:blue">Converting the GW information into the WCS geometry</span>

# %%
# %%time
pix_indices, nside = np.arange(len(data_ligo_hp)), hp.npix2nside(len(data_ligo_hp))
dec_hp, ra_hp = utils.IndexToDeclRa(pix_indices, nside)
hp_area = hp.nside2pixarea(nside)

# Reducing HealPix map to the approx WCS region
mask_hp_wcs = (
    (-(((ra_hp + 180) % 360) - 180) >= bin_edges_ra[:,-1:].min()) & (dec_hp >= bin_edges_dec[:1,:].max()) &
    (-(((ra_hp + 180) % 360) - 180) <= bin_edges_ra[:,:1].min()) & (dec_hp <= bin_edges_dec[-1:,:].max())
)
data_ligo_hp_wcs = data_ligo_hp[mask_hp_wcs]
dec_hp_wcs, ra_hp_wcs = dec_hp[mask_hp_wcs], -(ra_hp[mask_hp_wcs] + 180) % 360 - 180

# Now we integrate the probability for every bin in WCS
prob_gw_integrated = np.zeros((len(bin_edges_ra)-1, len(bin_edges_dec)-1))
num_hp_pixels = np.zeros((len(bin_edges_ra)-1, len(bin_edges_dec)-1))
mask_already_added_pixels = np.repeat(False, len(ra_hp_wcs))
for i in range(len(bin_edges_ra)-1):
    for j in range(len(bin_edges_ra[i])-1):
        mask_bin = (
            (ra_hp_wcs >= bin_edges_ra[i,j+1]) & (dec_hp_wcs >= bin_edges_dec[i,j]) &
            (ra_hp_wcs <= bin_edges_ra[i,j]) & (dec_hp_wcs <= bin_edges_dec[i+1,j+1])
        ) * (~mask_already_added_pixels)
        
        p = np.sum(data_ligo_hp_wcs[mask_bin]) * (
            bin_area[i,j].value / (np.sum(mask_bin) * hp_area)
        )
        prob_gw_integrated[i, j] = 0.0 if np.isnan(p) else p
        num_hp_pixels[i, j] = np.sum(mask_bin)

        mask_already_added_pixels = (mask_already_added_pixels | mask_bin)

norm_factor_gammapy_region = np.sum(prob_gw_integrated.ravel())
print(f"Geometry covers {norm_factor_gammapy_region * 100:.2f}% of the GW")

prob_gw = prob_gw_integrated
prob_gw = np.clip(prob_gw, a_min=1e-20, a_max=np.inf) # To avoid warnings in the SlurmOutput files
log_gw  = 2 * np.log(prob_gw)

masks_thresholds = []
for level in threshold_maps:
    cs = plt.contour(np.rad2deg(ra_grid), np.rad2deg(dec_grid), np.flip(data_ligo_2d, axis=1), levels=[level])
    paths = cs.get_paths() 
    plt.close()
    
    ra_wrapped = -((bin_c_ra + 180) % 360) + 180
    mask = [[
        any(p.contains_point((ra_wrapped[i, j], bin_c_dec[i, j])) for p in paths) for j in range(bin_c_ra.shape[1])
    ] for i in range(bin_c_ra.shape[0])]
    masks_thresholds.append(np.array(mask))
    
# We define separately the 95% region that is the one we are going to search
mask_threshold_95 = masks_thresholds[0]

utils.summary_gw_map(geom, bin_edges_ra, bin_edges_dec, prob_gw)
# Out:
# Geometry covers 98.91% of the GW
# CPU times: user 26 s, sys: 10.5 s, total: 36.4 s
# Wall time: 36.4 s

# %% [markdown]
# ### Reading the DL3 data and adding BKG hdu

# %%
data_store_real = DataStore.from_dir(dir_dl3)
print(f"Obs IDs in directory: {data_store_real.obs_ids}\n")

obs_collection_real = data_store_real.get_observations(
    obs_id = obs_ids, required_irf = ["aeff", "edisp", "psf"] 
)

# Reading background IRF information and adding it to the information
data_store_real.hdu_table.remove_rows(data_store_real.hdu_table["HDU_TYPE"]=="bkg") # Removing just in case cell is run 2 times
for obs_id in obs_ids:
    data_store_real = utils.add_bkg(data_store_real, obs_id, dir_dl3, dim_bkg=3, bkg_type=bkg_type)

data_store_real.hdu_table = data_store_real.hdu_table.copy() # Copy the table to update the data
obs_collection_real = data_store_real.get_observations(
    obs_id=obs_ids, required_irf=["aeff", "edisp", "psf"]
)

obs_table = data_store_real.obs_table[np.isin(data_store_real.obs_table["OBS_ID"], obs_ids)]
hdu_table = data_store_real.hdu_table[np.isin(data_store_real.hdu_table["OBS_ID"], obs_ids)]
print(f"Total livetime : {obs_table["LIVETIME"].to(u.min).sum():.2f}\n")
display(obs_table); display(hdu_table)
# Out:
# Obs IDs in directory: [17820 17821 17822 17823 17824 17825]
#
# Total livetime : 93.15 min
# <ObservationTable length=5>
# OBS_ID  DATE-OBS    TIME-OBS    DATE-END  ... N_TELS  TELLIST    INSTRUME
#                                           ...
# int64   bytes10     bytes12     bytes10   ... int64   bytes10    bytes10
# ------ ---------- ------------ ---------- ... ------ ---------- ----------
#  17821 2024-06-16 02:57:34.658 2024-06-16 ...      3 LST1_M1_M2 LST1_M1_M2
#  17822 2024-06-16 03:17:59.632 2024-06-16 ...      3 LST1_M1_M2 LST1_M1_M2
#  17823 2024-06-16 03:38:29.523 2024-06-16 ...      3 LST1_M1_M2 LST1_M1_M2
#  17824 2024-06-16 03:58:47.554 2024-06-16 ...      3 LST1_M1_M2 LST1_M1_M2
#  17825 2024-06-16 04:19:11.960 2024-06-16 ...      3 LST1_M1_M2 LST1_M1_M2
# <HDUIndexTable length=35>
# OBS_ID HDU_TYPE HDU_CLASS ...      HDU_NAME      SIZE
# int64   bytes8    bytes9  ...      bytes17      int64
# ------ -------- --------- ... ----------------- ------
#  17821   events    events ...            EVENTS 505719
#  17821      gti       gti ...               GTI 505719
#  17821 pointing  pointing ...          POINTING 505719
#  17821     aeff   aeff_2d ...    EFFECTIVE AREA 505719
#  17821    edisp  edisp_2d ... ENERGY DISPERSION 505719
#  17821      psf psf_table ...               PSF 505719
#  17822   events    events ...            EVENTS 650268
#  17822      gti       gti ...               GTI 650268
#  17822 pointing  pointing ...          POINTING 650268
#    ...      ...       ... ...               ...    ...
#  17825      gti       gti ...               GTI 836745
#  17825 pointing  pointing ...          POINTING 836745
#  17825     aeff   aeff_2d ...    EFFECTIVE AREA 836745
#  17825    edisp  edisp_2d ... ENERGY DISPERSION 836745
#  17825      psf psf_table ...               PSF 836745
#  17821      bkg    bkg_3d ...        BACKGROUND   2608
#  17822      bkg    bkg_3d ...        BACKGROUND   2608
#  17823      bkg    bkg_3d ...        BACKGROUND   2608
#  17824      bkg    bkg_3d ...        BACKGROUND   2608
#  17825      bkg    bkg_3d ...        BACKGROUND   2608

# %% [markdown]
# #### Showing summaries for all the data + IRFs inside the DL3

# %%
obs = obs_collection_real[0]
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    print("EVENTS SUMMARY:"); obs.events.peek(); plt.show()
    print("EFFECTIVE AREA SUMMARY:"); obs.aeff.peek(figsize=(9, 2.7)); plt.show()
    print("ENERGY DISPERSION SUMMARY:"); obs.edisp.peek(figsize=(9, 2.7)); plt.show()
    print("PSF SUMMARY:"); obs.psf.peek(figsize=(9, 2.7)); plt.show()
    print("BACKGROUND SUMMARY:"); obs.bkg.peek(figsize=(7, 5)); plt.show()
# Out:
# EVENTS SUMMARY:
# EFFECTIVE AREA SUMMARY:
# ENERGY DISPERSION SUMMARY:
# PSF SUMMARY:
# BACKGROUND SUMMARY:

# %% [markdown]
# #### We run the pipeline for the real data to compare

# %%
maker = MapDatasetMaker(selection=["counts", "background", "psf", "edisp", "exposure"])
maker_safe_mask = SafeMaskMaker(methods=["aeff-default", "offset-max"], offset_max=size_fov)
maker_ring = RingBackgroundMaker(r_in=ring_r_in, width=ring_width, exclusion_mask=None)

dataset_empty = MapDataset.create(geom, energy_axis_true=axis_energy_true)
dataset_stacked_real = MapDataset.create(geom, energy_axis_true=axis_energy_true) # dataset_stacked_real = MapDatasetOnOff.create(geom)

dataset_real, bkg_models = [], []
for i, obs in enumerate(obs_collection_real[:]):
    dataset = maker.run(dataset_empty.copy(), obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset_on_off = maker_ring.run(dataset)
    
    dataset_real.append(dataset_on_off)
    dataset_stacked_real.stack(dataset_on_off)
    
    utils.summary_folded_counts(dataset_on_off, bin_c_ra, obs, i, len(obs_collection_real))
    
    # Storing the normalized bkg model
    bkg_models.append(dataset_on_off.background.copy())

datasets_all_real = Datasets(dataset_real)

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    dataset_stacked_real.peek(figsize=(10, 6))
utils.summary_maps(
    dataset_real[0], geom, bin_edges_ra, bin_edges_dec, 
    data_ligo_2d, threshold_maps, source_coord, source_name
)

# %% [markdown]
# ### Defining the estimators needed
# * `ExcessMapEstimator`: We use it for TS computation as is faster, and less complex. It uses a TopHat smearing for convolving the reco maps.
# * `TSMapEstimator`: We use it for Flux computation. It takes more time but uses the full PSF for convolution of maps.

# %%
energy_edges = [axis_energy.edges[0], axis_energy.edges[-1]]
    
spatial_model = PointSpatialModel(lon_0=source_coord.ra, lat_0=source_coord.dec)
spectral_model = PowerLawSpectralModel(index=2)
model = SkyModel(spatial_model=spatial_model, spectral_model=spectral_model)

excess_estimator = ExcessMapEstimator(
    correlation_radius = correlation_radius,
    correlate_off = True,
    spectral_model = spectral_model,
    energy_edges = energy_edges,
    sum_over_energy_groups = True,
    selection_optional = ["ul"] # "all",
)

model = SkyModel(
    spectral_model = PowerLawSpectralModel(),
    spatial_model = PointSpatialModel(lon_0=source_coord.ra, lat_0=source_coord.dec),
)

ts_estimator = TSMapEstimator(
    model = model,
    energy_edges = energy_edges,
    sum_over_energy_groups = True,
    selection_optional = ["ul"] # "all",
)

# Changing the UL sigmas ot the one sided C.L.
ts_estimator.n_sigma_ul = norm.ppf(confidence_level)
excess_estimator.n_sigma_ul = norm.ppf(confidence_level)

# %% [markdown]
# ### Computing $ \Lambda$ for the real data
#
# Instead of computing the UL (just for following same procedure in the simulations) we first compute the "stats", that is much faster. This include TS and the related quantities.
#
# We compute our main parameter $\Lambda$, that is defined as the maximum TS' in the 95% region.

# %%
stats_real = convolved_map_dataset_counts_statistics(
    convolved_maps = _get_convolved_maps(
        dataset = dataset_stacked_real, 
        kernel = excess_estimator.estimate_kernel(dataset_stacked_real), 
        mask = excess_estimator.estimate_mask_default(dataset_stacked_real), 
        correlate_off = excess_estimator.correlate_off
    ),
    stat_type = "cash" # "wstat" or "cash", cash works with OnOffMapDataset
)

# %%
# Computing stats values ---
lik_alt  = cash(stats_real.n_on.sum(axis=0), stats_real.n_on.sum(axis=0))
lik_null = cash(stats_real.n_on.sum(axis=0), stats_real.mu_bkg.sum(axis=0))
ts_sign  = np.where((stats_real.n_on.sum(axis=0) - stats_real.mu_bkg.sum(axis=0)) >= 0.0, +1.0, -1.0)
ts  = np.where((lik_null - lik_alt) < 0.0, 0.0, (lik_null - lik_alt))
ts  = ts * ts_sign
ts2 = ts + 2 * np.log(prob_gw)

# Checking only in 95% area only ---
ts2_masked   = np.where(mask_threshold_95, ts2, np.nan)
ts2_argmax   = np.unravel_index(np.nanargmax(ts2_masked), ts2_masked.shape)

lambda_real  = np.nanmax(ts2_masked)
lambda_coord_real = SkyCoord(ra=bin_c_ra[ts2_argmax], dec=bin_c_dec[ts2_argmax], unit=u.deg, frame="icrs")

# %% [markdown]
# Plotting all the stats maps obtained.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9, 2.6), subplot_kw={"projection": geom.wcs})

tsmax = np.max(np.abs([np.nanmax(ts), np.nanmin(ts)]))
a1 = ax1.pcolormesh(
    bin_c_ra, bin_c_dec, ts, shading="nearest", transform=ax1.get_transform("icrs"), cmap="seismic", vmin=-tsmax, vmax=tsmax
)
a2 = ax2.pcolormesh(
    bin_c_ra, bin_c_dec, log_gw, shading="nearest", transform=ax2.get_transform("icrs"), cmap="cylon", vmin=-25, vmax=-13,
)
a3 = ax3.pcolormesh(
    bin_c_ra, bin_c_dec, ts2, shading="nearest", transform=ax3.get_transform("icrs"), cmap="viridis", vmin=-18
)
fig.colorbar(a1, ax=ax1, label="TS$=2\\log\\left(\\frac{\\mathcal{L}(n|n)}{\\mathcal{L}(n|n_{BKG})}\\right)$")
fig.colorbar(a2, ax=ax2, label=r"$2\log(P_{GW})$", extend="min")
fig.colorbar(a3, ax=ax3, label=r"TS$+2\log(P_{GW})$", extend="min")

for ax in [ax1, ax2, ax3]:
    lims = ax.get_xlim(), ax.get_ylim()
    ax.contour(
        data_ligo_2d, levels=threshold_maps, transform=ax.get_transform("icrs"), 
        origin="lower", linewidths=1, alpha=0.5,
        extent=[-180, 180, -90, 90], colors="w" if ax != ax1 else "k", 
    ); delta = 1.0
    ax.set_xlim(lims[0][0]+delta, lims[0][1]-delta); ax.set_ylim(lims[1][0]+delta, lims[1][1]-delta)

    ax.plot(source_coord.ra.deg, source_coord.dec.deg, "x", transform=ax.get_transform("icrs"),
            label="Pointing" if ax == ax2 else None, color="k", ls="")
    ax.set_xlabel("RA [deg]"); ax.grid()
    ax.coords[0].set_axislabel_position("b"); ax.coords[0].set_ticklabel_position("b")

ax3.plot(lambda_coord_real.ra.deg, lambda_coord_real.dec.deg, "x", color="r", ls="",
         transform=ax.get_transform("icrs"),label=f"Maximum = {lambda_real:.2f}")
    
for dec in (ax2.coords[1], ax3.coords[1]):
    dec.set_ticks_visible(False)
    dec.set_ticklabel_visible(False)

ax1.set(ylabel="DEC [deg]", title=f"TS ({axis_energy.edges[0]:.2f}-{axis_energy.edges[-1]:.2f})")
ax2.set_title("GW PDF"); ax3.set_title("TS'"); ax2.legend(frameon=False, loc=2, fontsize=8)
l3 = ax3.legend(frameon=False, loc=2, fontsize=8); [text.set_color("w") for text in l3.get_texts()]
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Getting IRFs, pointing, and timing information from real data
# Main goal is taking the `Datasets()` object of real data, and extract all the information:
# * IRFs
# * Livetime
# * Starting time
# * Pointings
#
# Then we have this empty object that we can use to do our simulations repeatedly.

# %%
# Getting the IRFs for each observation
obs_irfs, obs_time_ref, obs_pointing, obs_livetime = [], [], [], []
for i, obs_id in enumerate(obs_ids):
    hdu_tab = data_store_real.hdu_table[data_store_real.hdu_table["OBS_ID"] == obs_id]
    obs_tab = data_store_real.obs_table[data_store_real.obs_table["OBS_ID"] == obs_id]
    
    path_dl3 = os.path.join(dir_dl3, hdu_tab[hdu_tab["HDU_NAME"] == "EVENTS"]["FILE_NAME"][0])
    path_bkg = os.path.join(dir_dl3, hdu_tab[hdu_tab["HDU_NAME"] == "BACKGROUND"]["FILE_NAME"][0])
    
    _irfs_ = load_irf_dict_from_file(path_dl3)
    _irf_bkg_ = load_irf_dict_from_file(path_bkg)
    _irfs_.update(_irf_bkg_)

    obs_irfs.append(_irfs_)
    obs_time_ref.append(Time(f"{obs_tab['DATE-OBS'][0]} {obs_tab['TIME-OBS'][0]}", scale="utc"))
    obs_pointing.append(SkyCoord(ra=obs_tab["RA_PNT"][0], dec=obs_tab["DEC_PNT"][0], unit=u.deg, frame="icrs"))
    obs_livetime.append(np.sum(obs_tab["LIVETIME"]))
    print(f"\nRun {obs_id}\n - IRFs: {list(_irfs_.keys())}\n - Livetime {obs_livetime[-1]/60:.2f} min")
    print(f" - Time Ref {obs_time_ref[-1]}")
    print(f" - Pointing (RA={obs_tab['RA_PNT'][0]:.2f}, DEC={obs_tab['DEC_PNT'][0]:.2f})deg")
# Out:
# Run 17821
#  - IRFs: ['aeff', 'edisp', 'psf', 'bkg']
#  - Livetime 18.72 min
#  - Time Ref 2024-06-16 02:57:34.658
#  - Pointing (RA=6.90, DEC=45.83)deg
#
# Run 17822
#  - IRFs: ['aeff', 'edisp', 'psf', 'bkg']
#  - Livetime 18.43 min
#  - Time Ref 2024-06-16 03:17:59.632
#  - Pointing (RA=7.46, DEC=46.23)deg
#
# Run 17823
#  - IRFs: ['aeff', 'edisp', 'psf', 'bkg']
#  - Livetime 18.54 min
#  - Time Ref 2024-06-16 03:38:29.523
#  - Pointing (RA=7.50, DEC=45.41)deg
#
# Run 17824
#  - IRFs: ['aeff', 'edisp', 'psf', 'bkg']
#  - Livetime 18.67 min
#  - Time Ref 2024-06-16 03:58:47.554
#  - Pointing (RA=8.03, DEC=45.83)deg
#
# Run 17825
#  - IRFs: ['aeff', 'edisp', 'psf', 'bkg']
#  - Livetime 18.78 min
#  - Time Ref 2024-06-16 04:19:11.960
#  - Pointing (RA=6.92, DEC=45.81)deg

# %% [markdown]
# #### Filling the `Observation` object with the extracted data

# %%
observations = [Observation.create(
    obs_id = f"{i}",          
    pointing = FixedPointingInfo(obs_pointing[i]),
    livetime = obs_livetime[i] * u.s, 
    irfs = obs_irfs[i], 
    location = observing_location,
    reference_time = obs_time_ref[i],
) for i in range(len(obs_irfs))]

# %% [markdown]
# ### We create a empty unique dataset for the observations
#
# Only thing left is set the `model` and then simulate the events `.fake()` later.

# %%
maker = MapDatasetMaker(selection=["background", "psf", "edisp", "exposure"])
maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=size_fov)

dataset_empty = MapDataset.create(geom, energy_axis_true=axis_energy_true)
dataset_stacked_simulated = MapDataset.create(geom, energy_axis_true=axis_energy_true)

dataset_simulated = []
for i, obs in enumerate(observations):
    dataset = maker.run(dataset_empty.copy(), obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.background = bkg_models[i] # Setting the BKG model of real data
    dataset_simulated.append(dataset)
    dataset_stacked_simulated.stack(dataset)
    
    utils.summary_folded_counts(dataset, bin_c_ra, obs, i, len(observations))

dataset_all_simulated = Datasets(dataset_simulated)

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    dataset_stacked_simulated.peek(figsize=(10, 6))
utils.summary_maps(
    dataset_stacked_simulated, geom, bin_edges_ra, bin_edges_dec, data_ligo_2d, threshold_maps, source_coord, source_name
)

# %% [markdown]
# ### Computing correction factor for `ExcessMapEstimator`

# %%
# %%time
nsim_test = 100
test_amplitud = 1e-8 # s-1 cm-2 TeV-1 @ 1 TeV

model_source = Models([
    SkyModel(
        spatial_model = PointSpatialModel.from_position(coord_center),
        spectral_model = PowerLawSpectralModel(
            index=2, amplitude=f"{test_amplitud} cm-2 s-1 TeV-1", reference="1 TeV"
        ),
        temporal_model = ConstantTemporalModel(),
        name="model-simulated-test",
    )
])
true_flux_int = model_source[0].spectral_model.integral(
    excess_estimator.energy_edges[0], excess_estimator.energy_edges[-1]
)
containment_fluxes_test = []
for k in range(nsim_test):
    dataset_test = copy.deepcopy(dataset_stacked_simulated)

    dataset_test.models = model_source
    dataset_test.fake()
    dataset_test.models = None

    str_test = f"Running estimator for test amplitude {test_amplitud:.1e}"
    print(f"{str_test} s-1 cm-2 TeV-1 @ 1 TeV - {k+1}/{nsim_test}", end="\r")
    result_test = excess_estimator.run(dataset=dataset_test)
    
    central_index = (
        0, len(result_test.flux.data[0][0])//2, len((result_test.flux.data[0]).T[0])//2
    )
    containment_fluxes_test.append(
        result_test.flux.data[central_index]/(u.cm**2)/u.s / true_flux_int
    )
    
containment_factor = np.median(containment_fluxes_test)

fig, ax = plt.subplots(figsize=(4, 3))
ax.hist(containment_fluxes_test, 18, color="dodgerblue")
ax.axvline(containment_factor, color="k", ls="--", label=f"Median\n{nsim_test} sim")
ax.set(xlabel="Cont factor", ylabel="Counts", title=f"For corr radius {correlation_radius}")
ax.legend(frameon=False)
plt.show()
# Out:
# Running estimator for test amplitude 1.0e-08 s-1 cm-2 TeV-1 @ 1 TeV - 100/100
# CPU times: user 1min 2s, sys: 3.5 s, total: 1min 5s
# Wall time: 1min 6s

# %% [markdown]
# ### Computting the Sky-Map ULs for real data
# We compute the flux SkyMap using `ExcessEstimator`. The estimator that uses the top-hat kernel, so we need to correct those values for the containment of flux that we computed based on simulations.

# %%
print("Running Excess Map Estimator...")
maps_real = excess_estimator.run(dataset_stacked_real)

# Array fluxes ---
flux_uls = maps_real["flux_ul"].data.ravel() / containment_factor
flux_uls_95 = np.where(mask_threshold_95, maps_real["flux_ul"].data, np.nan).ravel() / containment_factor

fluxs = maps_real["flux"].data.ravel() / containment_factor
fluxs_95 = np.where(mask_threshold_95, maps_real["flux"].data, np.nan).ravel() / containment_factor

fig, ax = plt.subplots(figsize=(3, 2))

h = ax.hist(flux_uls, 40, histtype="stepfilled", color="lightgray", label="Total UL distribution")
ax.hist(flux_uls_95, h[1], histtype="step", color="k", label="ULs in 95%")

h = ax.hist(fluxs, 40, histtype="stepfilled", color="dodgerblue", label="Total flux distribution")
ax.hist(fluxs_95, h[1], histtype="step", color="b", label="Flux in 95%")

ax.set(xlabel="Flux UL [1 / (s cm2)]", ylabel="Counts", yscale="log")
ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}"); ax.legend(frameon=False, loc=(1.03, 0))
plt.show()
# Out:
# Running Excess Map Estimator...

# %% [markdown]
# ### Defining the needed input parameters in the simulations
#
# In order to perform the simulations we store the relevant information into a `.pkl` file:
# * The ExcessMapEstimator
# * The empty dataset to be simulated (all runs contained)
# * The GW SkyMap converted into WCS map
# * The mask of the Map for the 95% region
# * The containment factor for the flux

# %%
# From dl3 directory we check if is mono or stereo data
type_obs  = "mono" if "mono" in dir_dl3.lower() else "stereo" if "stereo" in dir_dl3.lower() else "unknown"

# Storing the empty dataset
path_pkl  = os.path.join("data", "tmp", f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}.pkl")
with open(path_pkl, "wb") as file:
    data_pkl = (dataset_stacked_simulated, excess_estimator, ts_estimator, prob_gw, data_ligo_hp, mask_threshold_95, containment_factor)
    pickle.dump(data_pkl, file)
    
# We can also store the real dataset (with real counts)
path_pkl_real  = os.path.join("data", "tmp", f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}__real.pkl")
with open(path_pkl_real, "wb") as file:
    data_pkl_real = (dataset_stacked_real, excess_estimator, ts_estimator, prob_gw, data_ligo_hp, mask_threshold_95, containment_factor)
    pickle.dump(data_pkl, file)

# %% [markdown]
# ### <span style="color:red">Extra: storing also the n-on and n-off</span>

# %%
# We can also store the real dataset (with real counts)
path_pkl_stats  = os.path.join("data", "tmp", f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}_STATS__real.pkl")
with open(path_pkl_stats, "wb") as file:
    pickle.dump(stats_real, file)

# %% [markdown]
# # Launching the BKG simulations

# %%
# %%time
n_sim_bkg = 20000
compute_uls = 0
amplitude_bkg = 0.0
overwrite = False

# First we check if the results file already exists
fname_results_bkg = f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}"
fname_results_bkg += f"_N_{n_sim_bkg}_f_{amplitude_bkg}_{'extended' if bool(compute_uls) else ''}.npz"
path_results_bkg = os.path.join("data", "results", fname_results_bkg)

# If data is not already produced
if not os.path.exists(path_results_bkg) or overwrite:
    
    # For the background there is no need of sending jobs as is only one simulation
    # Can take O(5-10min) for a decent amount of statistics to compute the distribution
    utils.perform_n_simulations(
        n_sim = n_sim_bkg,
        amplitude = amplitude_bkg,
        file_input = path_pkl,
        file_output = path_results_bkg,
        compute_uls = compute_uls
    )
else:
    print(f"Data already exists")

# Then we load the data always from the files
print(f"\nLoading for N={n_sim_bkg}...\n")
data_bkg = np.load(path_results_bkg, allow_pickle=True)

# Computing the statistics ---
# Lambda parameter
lambda_bkg = data_bkg["lambda_data"]
lambda_ra_bkg, lambda_dec_bkg = data_bkg["lambda_ra"], data_bkg["lambda_dec"]
# Maximum of TS distribution
tsmax_bkg = data_bkg["tsmax"]
tsmax_ra_bkg, tsmax_dec_bkg = data_bkg["tsmax_ra"], data_bkg["tsmax_dec"]
# Storing th distributions
ts_dist  = data_bkg["ts_dist"]
ts2_dist = data_bkg["ts2_dist"]
# The position of simulated source
f_ra_bkg, f_dec_bkg = data_bkg["f_ra"], data_bkg["f_dec"]

if compute_uls:
    # If we need to compute ULs we also read flux maps
    ulmax_bkg = data_bkg["ulmax"]; ul_dist = data_bkg["ul_dist"]
    ulmax_ra_bkg, ulmax_dec_bkg = data_bkg["ulmax_ra"], data_bkg["ulmax_dec"]
# Out:
# Producing 20000 simulations without computing the flux maps.
# Setting up everything...
#
# Writing file:20000/20000
#  --> data/results/S240615dg_stereo_E_0.6_20.0_N_20000_f_0.0_.npz
#
# Loading for N=20000...
#
# CPU times: user 2h 58min 33s, sys: 7min 42s, total: 3h 6min 16s
# Wall time: 3h 9min 37s

# %% [markdown]
# Then we can compute some extra parameters of comprobations:
# * `p-value` The fraction of simulations above the real value.
# * `significance` Converting the p-value to fraction of the normal distribution.
# * `lambda median` The median value of BKG distribution, that we will use as reference.

# %%
p_value = len(lambda_bkg[lambda_bkg > lambda_real]) / len(lambda_bkg)
significance = norm.ppf(1 - p_value)
lambda_bkg_m = np.median(lambda_bkg)

# Lambda map
map_lambda_bkg = Map.from_geom(geom=geom_image)
map_lambda_bkg.fill_by_coord({"lon": lambda_ra_bkg * u.deg, "lat": lambda_dec_bkg * u.deg,})
# TS map
map_ts_bkg = Map.from_geom(geom=geom_image)
map_ts_bkg.fill_by_coord({"lon": tsmax_ra_bkg * u.deg, "lat": tsmax_dec_bkg * u.deg,})
# Position of simulated sources maps
map_source_sim = Map.from_geom(geom=geom_image)
map_source_sim.fill_by_coord({"lon": f_ra_bkg * u.deg, "lat": f_dec_bkg * u.deg,})

if compute_uls:
    # Flux ULs
    map_ul_bkg = Map.from_geom(geom=geom_image)
    map_ul_bkg.fill_by_coord({"lon": ulmax_ra_bkg * u.deg, "lat": ulmax_dec_bkg * u.deg,})


nbins_lambda = 100
min_l_bkg, max_l_bkg = lambda_bkg.min(), lambda_bkg.max()
bins_lambda = np.linspace(min_l_bkg, max_l_bkg, nbins_lambda)

# %% [markdown]
# #### Crosscheck plot + BKG $\Lambda$ distribution

# %%
fig = plt.figure(figsize=(7, 5))
gs = GridSpec(2, 3, figure=fig, height_ratios=[2, 1])
axt = fig.add_subplot(gs[0, :])
ax1 = fig.add_subplot(gs[1, 0], projection=geom.wcs)
ax2 = fig.add_subplot(gs[1, 1], projection=geom.wcs)
ax3 = fig.add_subplot(gs[1, 2], projection=geom.wcs)

axt.hist(lambda_bkg, bins_lambda, color="royalblue", 
         density=True, histtype="stepfilled", label=f"BKG sim\nN={len(lambda_bkg)}")
axt.text(
    0.85, 0.87, f"p-value={p_value:.2f}\nsignificance={significance:.2f} $\\sigma$",
    ha="center", va="center", transform=axt.transAxes
)
axt.axvline(lambda_real, color="k", ls="--", label=f"Real data\n$\\Lambda=${lambda_real:.2f}")
axt.axvline(lambda_bkg_m, color="darkblue", ls=":", label=f"BKG median\n$\\Lambda=${lambda_bkg_m:.2f}")

for ax, cmap, mapa, lab in zip(
    [ax1, ax2, ax3], ["magma", "magma", "cividis"],
    [map_lambda_bkg, map_ts_bkg, map_source_sim], 
    [r"$\\Lambda$", r"$TS_{\text{MAX}}$", "Simulated sources"]
):
    pc = ax.pcolormesh(
        bin_edges_ra, bin_edges_dec, mapa.data, cmap=cmap,
        transform=ax.get_transform("icrs")
    )

    lims = ax.get_xlim(), ax.get_ylim()
    ax.contour(
        data_ligo_2d, levels=threshold_maps, transform=ax.get_transform("icrs"), origin="lower",
        extent=[-180, 180, -90, 90], colors="w", linewidths=1,
    )
    ax.set_xlim(lims[0][0], lims[0][1]); ax.set_ylim(lims[1][0], lims[1][1])
    ax.coords[0].set_axislabel_position("b"); ax.coords[0].set_ticklabel_position("b")

axt.legend(frameon=False, loc=4)
axt.set_xlabel("$\\Lambda$"); axt.set_ylabel("Normalized counts")
for ax in [ax1, ax2, ax3]:
    ax.set_xlabel("RA [deg]")
ax1.set_ylabel("DEC [deg]"); ax2.set_ylabel(" "); ax3.set_ylabel(" ")
ax1.set_title("$\\Lambda_{BKG}$ ($TS'_{max}$)")
ax2.set_title("$TS_{max}$"); ax3.set_title("Source positions $(F=0)$")
axt.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
fig.tight_layout()

plt.show()

# %% [markdown]
# ### <span style="color:red">Extra: plotting n-on and n-off</span>

# %%
random_pixel = (
    np.random.randint(0, bin_edges_ra.shape[0]), np.random.randint(0, bin_edges_ra.shape[1])
)

n_on_real = stats_real.n_on.sum(axis=0)[random_pixel]
n_off_real = stats_real.n_bkg.sum(axis=0)[random_pixel]

n_on_bkg, n_off_bkg = [], []
for s in data_bkg["stats"]:
    n_on_bkg.append(s.n_on.sum(axis=0)[random_pixel])
    n_off_bkg.append(s.n_bkg.sum(axis=0)[random_pixel])

# %%
fig, ax = plt.subplots()
ax.set_title(f"Random pixel selection: {random_pixel}")

plt.axvline(n_on_real, color="b", ls="-", label="n-ON real")
plt.axvline(n_off_real, color="r", ls="--", label="n-OFF real (fixed)")
plt.hist(n_on_bkg, 50, color="b", alpha=0.5, label="BKG realisations")
plt.legend(frameon=False, loc=2)
# plt.hist(n_off_bkg, 100, color="r", alpha=0.5)
plt.xlabel("number of counts (sum over E)")
plt.show()

# %% [markdown]
# # Sending jobs for flux simulations

# %%
n_sim_f = 10500
amplitudes = np.logspace(-12, -10, 150)
compute_uls_f = 0
overwrite = False

for amplitude in amplitudes:
    fname_results_f  = f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}"
    fname_results_f += f"_N_{n_sim_f}_f_{amplitude}_{'extended' if bool(compute_uls_f) else ''}.npz"
    path_results_f   = os.path.join("data", "results", fname_results_f)
    
    # First we check if the results file already exists
    if os.path.exists(path_results_f):
        print(f"Flux Amplitude: {amplitude:.2e} - Results already exist")
        if overwrite:
            print(f"Overwritting...")
        else:
            continue
        
    _command_ = f"python utils.py {n_sim_f} {amplitude} {path_pkl} {path_results_f} {compute_uls_f}"    
    
    str_output = f"-o ./data/slurm_output/job_simulate_{type_obs}_F{amplitude:.4e}_N{n_sim_f}.out"
    slurm_command = f"sbatch -p short --mem=20000 -J simulate_source {str_output} --wrap='{_command_}'"

    subprocess.run(slurm_command, shell=True, check=True)
# Out:
# Submitted batch job 53386315
# Submitted batch job 53386316
# Submitted batch job 53386317
# Submitted batch job 53386318
# Submitted batch job 53386319
# Submitted batch job 53386320
# Submitted batch job 53386321
# Submitted batch job 53386322
# Submitted batch job 53386323
# Submitted batch job 53386324
# Submitted batch job 53386325
# Submitted batch job 53386326
# Submitted batch job 53386327
# Submitted batch job 53386328
# Submitted batch job 53386329
# Submitted batch job 53386330
# Submitted batch job 53386331
# Submitted batch job 53386332
# Submitted batch job 53386333
# Submitted batch job 53386334
# Submitted batch job 53386335
# Submitted batch job 53386336
# Submitted batch job 53386337
# Submitted batch job 53386338
# Submitted batch job 53386339
# Submitted batch job 53386340
# Submitted batch job 53386341
# Submitted batch job 53386342
# Submitted batch job 53386343
# Submitted batch job 53386344
# Submitted batch job 53386345
# Submitted batch job 53386346
# Submitted batch job 53386347
# Submitted batch job 53386348
# Submitted batch job 53386349
# Submitted batch job 53386350
# Submitted batch job 53386351
# Submitted batch job 53386352
# Submitted batch job 53386353
# Submitted batch job 53386354
# Submitted batch job 53386355
# Submitted batch job 53386356
# Submitted batch job 53386357
# Submitted batch job 53386358
# Submitted batch job 53386359
# Submitted batch job 53386360
# Submitted batch job 53386361
# Submitted batch job 53386362
# Submitted batch job 53386363
# Submitted batch job 53386364
# Submitted batch job 53386365
# Submitted batch job 53386366
# Submitted batch job 53386367
# Submitted batch job 53386368
# Submitted batch job 53386369
# Submitted batch job 53386370
# Submitted batch job 53386371
# Submitted batch job 53386372
# Submitted batch job 53386373
# Submitted batch job 53386374
# Submitted batch job 53386375
# Submitted batch job 53386376
# Submitted batch job 53386377
# Submitted batch job 53386378
# Submitted batch job 53386379
# Submitted batch job 53386380
# Submitted batch job 53386381
# Submitted batch job 53386382
# Submitted batch job 53386383
# Submitted batch job 53386384
# Submitted batch job 53386385
# Submitted batch job 53386386
# Submitted batch job 53386387
# Submitted batch job 53386388
# Submitted batch job 53386389
# Submitted batch job 53386390
# Submitted batch job 53386391
# Submitted batch job 53386392
# Submitted batch job 53386393
# Submitted batch job 53386394
# Submitted batch job 53386395
# Submitted batch job 53386396
# Submitted batch job 53386397
# Submitted batch job 53386398
# Submitted batch job 53386399
# Submitted batch job 53386400
# Submitted batch job 53386401
# Submitted batch job 53386402
# Submitted batch job 53386403
# Submitted batch job 53386404
# Submitted batch job 53386405
# Submitted batch job 53386406
# Submitted batch job 53386407
# Submitted batch job 53386408
# Submitted batch job 53386409
# Submitted batch job 53386410
# Submitted batch job 53386411
# Submitted batch job 53386412
# Submitted batch job 53386413
# Submitted batch job 53386414
# Submitted batch job 53386415
# Submitted batch job 53386416
# Submitted batch job 53386417
# Submitted batch job 53386418
# Submitted batch job 53386419
# Submitted batch job 53386420
# Submitted batch job 53386421
# Submitted batch job 53386422
# Submitted batch job 53386423
# Submitted batch job 53386424
# Submitted batch job 53386425
# Submitted batch job 53386426
# Submitted batch job 53386427
# Submitted batch job 53386428
# Submitted batch job 53386429
# Submitted batch job 53386430
# Submitted batch job 53386431
# Submitted batch job 53386432
# Submitted batch job 53386433
# Submitted batch job 53386434
# Submitted batch job 53386435
# Submitted batch job 53386436
# Submitted batch job 53386437
# Submitted batch job 53386438
# Submitted batch job 53386439
# Submitted batch job 53386440
# Submitted batch job 53386441
# Submitted batch job 53386442
# Submitted batch job 53386443
# Submitted batch job 53386444
# Submitted batch job 53386445
# Submitted batch job 53386446
# Submitted batch job 53386447
# Submitted batch job 53386448
# Submitted batch job 53386449
# Submitted batch job 53386450
# Submitted batch job 53386451
# Submitted batch job 53386452
# Submitted batch job 53386453
# Submitted batch job 53386454
# Submitted batch job 53386455
# Submitted batch job 53386456
# Submitted batch job 53386457
# Submitted batch job 53386458
# Submitted batch job 53386459
# Submitted batch job 53386460
# Submitted batch job 53386461
# Submitted batch job 53386462
# Submitted batch job 53386463
# Submitted batch job 53386464

# %%
# !squeue -u juan.jimenez
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           53386317     short simulate juan.jim PD       0:00      1 (Priority)
#           53386318     short simulate juan.jim PD       0:00      1 (Priority)
#           53386319     short simulate juan.jim PD       0:00      1 (Priority)
#           53386320     short simulate juan.jim PD       0:00      1 (Priority)
#           53386321     short simulate juan.jim PD       0:00      1 (Priority)
#           53386322     short simulate juan.jim PD       0:00      1 (Priority)
#           53386323     short simulate juan.jim PD       0:00      1 (Priority)
#           53386324     short simulate juan.jim PD       0:00      1 (Priority)
#           53386325     short simulate juan.jim PD       0:00      1 (Priority)
#           53386326     short simulate juan.jim PD       0:00      1 (Priority)
#           53386327     short simulate juan.jim PD       0:00      1 (Priority)
#           53386329     short simulate juan.jim PD       0:00      1 (Priority)
#           53386328     short simulate juan.jim PD       0:00      1 (Priority)
#           53386316     short simulate juan.jim PD       0:00      1 (Resources)
#           53386330     short simulate juan.jim PD       0:00      1 (Priority)
#           53386331     short simulate juan.jim PD       0:00      1 (Priority)
#           53386332     short simulate juan.jim PD       0:00      1 (Priority)
#           53386333     short simulate juan.jim PD       0:00      1 (Priority)
#           53386334     short simulate juan.jim PD       0:00      1 (Priority)
#           53386335     short simulate juan.jim PD       0:00      1 (Priority)
#           53386336     short simulate juan.jim PD       0:00      1 (Priority)
#           53386337     short simulate juan.jim PD       0:00      1 (Priority)
#           53386338     short simulate juan.jim PD       0:00      1 (Priority)
#           53386339     short simulate juan.jim PD       0:00      1 (Priority)
#           53386340     short simulate juan.jim PD       0:00      1 (Priority)
#           53386341     short simulate juan.jim PD       0:00      1 (Priority)
#           53386342     short simulate juan.jim PD       0:00      1 (Priority)
#           53386343     short simulate juan.jim PD       0:00      1 (Priority)
#           53386344     short simulate juan.jim PD       0:00      1 (Priority)
#           53386345     short simulate juan.jim PD       0:00      1 (Priority)
#           53386346     short simulate juan.jim PD       0:00      1 (Priority)
#           53386347     short simulate juan.jim PD       0:00      1 (Priority)
#           53386348     short simulate juan.jim PD       0:00      1 (Priority)
#           53386349     short simulate juan.jim PD       0:00      1 (Priority)
#           53386350     short simulate juan.jim PD       0:00      1 (Priority)
#           53386351     short simulate juan.jim PD       0:00      1 (Priority)
#           53386352     short simulate juan.jim PD       0:00      1 (Priority)
#           53386353     short simulate juan.jim PD       0:00      1 (Priority)
#           53386354     short simulate juan.jim PD       0:00      1 (Priority)
#           53386355     short simulate juan.jim PD       0:00      1 (Priority)
#           53386356     short simulate juan.jim PD       0:00      1 (Priority)
#           53386357     short simulate juan.jim PD       0:00      1 (Priority)
#           53386358     short simulate juan.jim PD       0:00      1 (Priority)
#           53386359     short simulate juan.jim PD       0:00      1 (Priority)
#           53386360     short simulate juan.jim PD       0:00      1 (Priority)
#           53386361     short simulate juan.jim PD       0:00      1 (Priority)
#           53386362     short simulate juan.jim PD       0:00      1 (Priority)
#           53386363     short simulate juan.jim PD       0:00      1 (Priority)
#           53386364     short simulate juan.jim PD       0:00      1 (Priority)
#           53386365     short simulate juan.jim PD       0:00      1 (Priority)
#           53386366     short simulate juan.jim PD       0:00      1 (Priority)
#           53386367     short simulate juan.jim PD       0:00      1 (Priority)
#           53386368     short simulate juan.jim PD       0:00      1 (Priority)
#           53386369     short simulate juan.jim PD       0:00      1 (Priority)
#           53386370     short simulate juan.jim PD       0:00      1 (Priority)
#           53386371     short simulate juan.jim PD       0:00      1 (Priority)
#           53386372     short simulate juan.jim PD       0:00      1 (Priority)
#           53386373     short simulate juan.jim PD       0:00      1 (Priority)
#           53386374     short simulate juan.jim PD       0:00      1 (Priority)
#           53386375     short simulate juan.jim PD       0:00      1 (Priority)
#           53386376     short simulate juan.jim PD       0:00      1 (Priority)
#           53386377     short simulate juan.jim PD       0:00      1 (Priority)
#           53386378     short simulate juan.jim PD       0:00      1 (Priority)
#           53386379     short simulate juan.jim PD       0:00      1 (Priority)
#           53386380     short simulate juan.jim PD       0:00      1 (Priority)
#           53386381     short simulate juan.jim PD       0:00      1 (Priority)
#           53386382     short simulate juan.jim PD       0:00      1 (Priority)
#           53386383     short simulate juan.jim PD       0:00      1 (Priority)
#           53386384     short simulate juan.jim PD       0:00      1 (Priority)
#           53386385     short simulate juan.jim PD       0:00      1 (Priority)
#           53386386     short simulate juan.jim PD       0:00      1 (Priority)
#           53386387     short simulate juan.jim PD       0:00      1 (Priority)
#           53386388     short simulate juan.jim PD       0:00      1 (Priority)
#           53386389     short simulate juan.jim PD       0:00      1 (Priority)
#           53386390     short simulate juan.jim PD       0:00      1 (Priority)
#           53386391     short simulate juan.jim PD       0:00      1 (Priority)
#           53386392     short simulate juan.jim PD       0:00      1 (Priority)
#           53386393     short simulate juan.jim PD       0:00      1 (Priority)
#           53386394     short simulate juan.jim PD       0:00      1 (Priority)
#           53386395     short simulate juan.jim PD       0:00      1 (Priority)
#           53386396     short simulate juan.jim PD       0:00      1 (Priority)
#           53386397     short simulate juan.jim PD       0:00      1 (Priority)
#           53386398     short simulate juan.jim PD       0:00      1 (Priority)
#           53386399     short simulate juan.jim PD       0:00      1 (Priority)
#           53386400     short simulate juan.jim PD       0:00      1 (Priority)
#           53386401     short simulate juan.jim PD       0:00      1 (Priority)
#           53386402     short simulate juan.jim PD       0:00      1 (Priority)
#           53386403     short simulate juan.jim PD       0:00      1 (Priority)
#           53386404     short simulate juan.jim PD       0:00      1 (Priority)
#           53386405     short simulate juan.jim PD       0:00      1 (Priority)
#           53386406     short simulate juan.jim PD       0:00      1 (Priority)
#           53386407     short simulate juan.jim PD       0:00      1 (Priority)
#           53386408     short simulate juan.jim PD       0:00      1 (Priority)
#           53386409     short simulate juan.jim PD       0:00      1 (Priority)
#           53386410     short simulate juan.jim PD       0:00      1 (Priority)
#           53386411     short simulate juan.jim PD       0:00      1 (Priority)
#           53386412     short simulate juan.jim PD       0:00      1 (Priority)
#           53386413     short simulate juan.jim PD       0:00      1 (Priority)
#           53386414     short simulate juan.jim PD       0:00      1 (Priority)
#           53386415     short simulate juan.jim PD       0:00      1 (Priority)
#           53386416     short simulate juan.jim PD       0:00      1 (Priority)
#           53386417     short simulate juan.jim PD       0:00      1 (Priority)
#           53386418     short simulate juan.jim PD       0:00      1 (Priority)
#           53386419     short simulate juan.jim PD       0:00      1 (Priority)
#           53386420     short simulate juan.jim PD       0:00      1 (Priority)
#           53386421     short simulate juan.jim PD       0:00      1 (Priority)
#           53386422     short simulate juan.jim PD       0:00      1 (Priority)
#           53386423     short simulate juan.jim PD       0:00      1 (Priority)
#           53386424     short simulate juan.jim PD       0:00      1 (Priority)
#           53386425     short simulate juan.jim PD       0:00      1 (Priority)
#           53386426     short simulate juan.jim PD       0:00      1 (Priority)
#           53386427     short simulate juan.jim PD       0:00      1 (Priority)
#           53386428     short simulate juan.jim PD       0:00      1 (Priority)
#           53386429     short simulate juan.jim PD       0:00      1 (Priority)
#           53386430     short simulate juan.jim PD       0:00      1 (Priority)
#           53386431     short simulate juan.jim PD       0:00      1 (Priority)
#           53386432     short simulate juan.jim PD       0:00      1 (Priority)
#           53386433     short simulate juan.jim PD       0:00      1 (Priority)
#           53386434     short simulate juan.jim PD       0:00      1 (Priority)
#           53386435     short simulate juan.jim PD       0:00      1 (Priority)
#           53386436     short simulate juan.jim PD       0:00      1 (Priority)
#           53386437     short simulate juan.jim PD       0:00      1 (Priority)
#           53386438     short simulate juan.jim PD       0:00      1 (Priority)
#           53386439     short simulate juan.jim PD       0:00      1 (Priority)
#           53386440     short simulate juan.jim PD       0:00      1 (Priority)
#           53386441     short simulate juan.jim PD       0:00      1 (Priority)
#           53386442     short simulate juan.jim PD       0:00      1 (Priority)
#           53386443     short simulate juan.jim PD       0:00      1 (Priority)
#           53386444     short simulate juan.jim PD       0:00      1 (Priority)
#           53386445     short simulate juan.jim PD       0:00      1 (Priority)
#           53386446     short simulate juan.jim PD       0:00      1 (Priority)
#           53386447     short simulate juan.jim PD       0:00      1 (Priority)
#           53386448     short simulate juan.jim PD       0:00      1 (Priority)
#           53386449     short simulate juan.jim PD       0:00      1 (Priority)
#           53386450     short simulate juan.jim PD       0:00      1 (Priority)
#           53386451     short simulate juan.jim PD       0:00      1 (None)
#           53386452     short simulate juan.jim PD       0:00      1 (None)
#           53386453     short simulate juan.jim PD       0:00      1 (None)
#           53386454     short simulate juan.jim PD       0:00      1 (None)
#           53386455     short simulate juan.jim PD       0:00      1 (None)
#           53386456     short simulate juan.jim PD       0:00      1 (None)
#           53386457     short simulate juan.jim PD       0:00      1 (None)
#           53386458     short simulate juan.jim PD       0:00      1 (None)
#           53386459     short simulate juan.jim PD       0:00      1 (None)
#           53386460     short simulate juan.jim PD       0:00      1 (None)
#           53386461     short simulate juan.jim PD       0:00      1 (None)
#           53386462     short simulate juan.jim PD       0:00      1 (None)
#           53386463     short simulate juan.jim PD       0:00      1 (None)
#           53386464     short simulate juan.jim PD       0:00      1 (None)
#           53386312     short simulate juan.jim  R       0:02      1 cp43
#           53386313     short simulate juan.jim  R       0:02      1 cp43
#           53386314     short simulate juan.jim  R       0:02      1 cp43
#           53386315     short simulate juan.jim  R       0:02      1 cp43
#           53386311     short simulate juan.jim  R       0:06      1 cp44
#           53386310     short simulate juan.jim  R       0:17      1 cp29
#           53386309     short simulate juan.jim  R       0:38      1 cp23
#           53386308     short simulate juan.jim  R       1:03      1 cp53
#           53386292     short simulate juan.jim  R       1:13      1 cp16
#           53386293     short simulate juan.jim  R       1:13      1 cp32
#           53386294     short simulate juan.jim  R       1:13      1 cp32
#           53386295     short simulate juan.jim  R       1:13      1 cp32
#           53386296     short simulate juan.jim  R       1:13      1 cp32
#           53386297     short simulate juan.jim  R       1:13      1 cp54
#           53386298     short simulate juan.jim  R       1:13      1 cp47
#           53386299     short simulate juan.jim  R       1:13      1 cp47
#           53386300     short simulate juan.jim  R       1:13      1 cp47
#           53386301     short simulate juan.jim  R       1:13      1 cp47
#           53386302     short simulate juan.jim  R       1:13      1 cp47
#           53386303     short simulate juan.jim  R       1:13      1 cp47
#           53386304     short simulate juan.jim  R       1:13      1 cp47
#           53386305     short simulate juan.jim  R       1:13      1 cp47
#           53386306     short simulate juan.jim  R       1:13      1 cp47
#           53386307     short simulate juan.jim  R       1:13      1 cp47
#           53386269     short simulate juan.jim  R       1:14      1 cp50
#           53386270     short simulate juan.jim  R       1:14      1 cp31
#           53386271     short simulate juan.jim  R       1:14      1 cp31
#           53386272     short simulate juan.jim  R       1:14      1 cp31
#           53386273     short simulate juan.jim  R       1:14      1 cp53
#           53386274     short simulate juan.jim  R       1:14      1 cp53
#           53386275     short simulate juan.jim  R       1:14      1 cp53
#           53386276     short simulate juan.jim  R       1:14      1 cp53
#           53386277     short simulate juan.jim  R       1:14      1 cp53
#           53386278     short simulate juan.jim  R       1:14      1 cp53
#           53386279     short simulate juan.jim  R       1:14      1 cp53
#           53386280     short simulate juan.jim  R       1:14      1 cp53
#           53386281     short simulate juan.jim  R       1:14      1 cp53
#           53386282     short simulate juan.jim  R       1:14      1 cp53
#           53386283     short simulate juan.jim  R       1:14      1 cp45
#           53386284     short simulate juan.jim  R       1:14      1 cp16
#           53386285     short simulate juan.jim  R       1:14      1 cp16
#           53386286     short simulate juan.jim  R       1:14      1 cp16
#           53386287     short simulate juan.jim  R       1:14      1 cp16
#           53386288     short simulate juan.jim  R       1:14      1 cp16
#           53386289     short simulate juan.jim  R       1:14      1 cp16
#           53386290     short simulate juan.jim  R       1:14      1 cp16
#           53386291     short simulate juan.jim  R       1:14      1 cp16
#           53386218     short simulate juan.jim  R       1:16      1 cp40
#           53386219     short simulate juan.jim  R       1:16      1 cp40
#           53386220     short simulate juan.jim  R       1:16      1 cp40
#           53386221     short simulate juan.jim  R       1:16      1 cp40
#           53386222     short simulate juan.jim  R       1:16      1 cp40
#           53386223     short simulate juan.jim  R       1:16      1 cp40
#           53386224     short simulate juan.jim  R       1:16      1 cp40
#           53386225     short simulate juan.jim  R       1:16      1 cp40
#           53386226     short simulate juan.jim  R       1:16      1 cp40
#           53386227     short simulate juan.jim  R       1:16      1 cp42
#           53386228     short simulate juan.jim  R       1:16      1 cp42
#           53386229     short simulate juan.jim  R       1:16      1 cp42
#           53386230     short simulate juan.jim  R       1:16      1 cp42
#           53386231     short simulate juan.jim  R       1:16      1 cp42
#           53386232     short simulate juan.jim  R       1:16      1 cp42
#           53386233     short simulate juan.jim  R       1:16      1 cp42
#           53386234     short simulate juan.jim  R       1:16      1 cp42
#           53386235     short simulate juan.jim  R       1:16      1 cp28
#           53386236     short simulate juan.jim  R       1:16      1 cp28
#           53386237     short simulate juan.jim  R       1:16      1 cp43
#           53386238     short simulate juan.jim  R       1:16      1 cp10
#           53386239     short simulate juan.jim  R       1:16      1 cp10
#           53386240     short simulate juan.jim  R       1:16      1 cp10
#           53386241     short simulate juan.jim  R       1:16      1 cp10
#           53386242     short simulate juan.jim  R       1:16      1 cp10
#           53386243     short simulate juan.jim  R       1:16      1 cp10
#           53386244     short simulate juan.jim  R       1:16      1 cp10
#           53386245     short simulate juan.jim  R       1:16      1 cp29
#           53386246     short simulate juan.jim  R       1:16      1 cp29
#           53386247     short simulate juan.jim  R       1:16      1 cp29
#           53386248     short simulate juan.jim  R       1:16      1 cp29
#           53386249     short simulate juan.jim  R       1:16      1 cp29
#           53386250     short simulate juan.jim  R       1:16      1 cp29
#           53386251     short simulate juan.jim  R       1:16      1 cp29
#           53386252     short simulate juan.jim  R       1:16      1 cp29
#           53386253     short simulate juan.jim  R       1:16      1 cp29
#           53386254     short simulate juan.jim  R       1:16      1 cp29
#           53386255     short simulate juan.jim  R       1:16      1 cp44
#           53386256     short simulate juan.jim  R       1:16      1 cp44
#           53386257     short simulate juan.jim  R       1:16      1 cp44
#           53386258     short simulate juan.jim  R       1:16      1 cp44
#           53386259     short simulate juan.jim  R       1:16      1 cp44
#           53386260     short simulate juan.jim  R       1:16      1 cp12
#           53386261     short simulate juan.jim  R       1:16      1 cp30
#           53386262     short simulate juan.jim  R       1:16      1 cp50
#           53386263     short simulate juan.jim  R       1:16      1 cp50
#           53386264     short simulate juan.jim  R       1:16      1 cp50
#           53386265     short simulate juan.jim  R       1:16      1 cp50
#           53386266     short simulate juan.jim  R       1:16      1 cp50
#           53386267     short simulate juan.jim  R       1:16      1 cp50
#           53386268     short simulate juan.jim  R       1:16      1 cp50
#           53386174     short simulate juan.jim  R       1:20      1 cp19
#           53386175     short simulate juan.jim  R       1:20      1 cp19
#           53386176     short simulate juan.jim  R       1:20      1 cp19
#           53386177     short simulate juan.jim  R       1:20      1 cp37
#           53386178     short simulate juan.jim  R       1:20      1 cp37
#           53386179     short simulate juan.jim  R       1:20      1 cp37
#           53386180     short simulate juan.jim  R       1:20      1 cp37
#           53386181     short simulate juan.jim  R       1:20      1 cp37
#           53386182     short simulate juan.jim  R       1:20      1 cp37
#           53386183     short simulate juan.jim  R       1:20      1 cp37
#           53386184     short simulate juan.jim  R       1:20      1 cp37
#           53386185     short simulate juan.jim  R       1:20      1 cp37
#           53386186     short simulate juan.jim  R       1:20      1 cp37
#           53386187     short simulate juan.jim  R       1:20      1 cp37
#           53386188     short simulate juan.jim  R       1:20      1 cp37
#           53386189     short simulate juan.jim  R       1:20      1 cp23
#           53386190     short simulate juan.jim  R       1:20      1 cp23
#           53386191     short simulate juan.jim  R       1:20      1 cp23
#           53386192     short simulate juan.jim  R       1:20      1 cp38
#           53386193     short simulate juan.jim  R       1:20      1 cp38
#           53386194     short simulate juan.jim  R       1:20      1 cp38
#           53386195     short simulate juan.jim  R       1:20      1 cp38
#           53386196     short simulate juan.jim  R       1:20      1 cp38
#           53386197     short simulate juan.jim  R       1:20      1 cp38
#           53386198     short simulate juan.jim  R       1:20      1 cp38
#           53386199     short simulate juan.jim  R       1:20      1 cp38
#           53386200     short simulate juan.jim  R       1:20      1 cp38
#           53386201     short simulate juan.jim  R       1:20      1 cp38
#           53386202     short simulate juan.jim  R       1:20      1 cp38
#           53386203     short simulate juan.jim  R       1:20      1 cp24
#           53386204     short simulate juan.jim  R       1:20      1 cp24
#           53386205     short simulate juan.jim  R       1:20      1 cp24
#           53386206     short simulate juan.jim  R       1:20      1 cp24
#           53386207     short simulate juan.jim  R       1:20      1 cp24
#           53386208     short simulate juan.jim  R       1:20      1 cp39
#           53386209     short simulate juan.jim  R       1:20      1 cp39
#           53386210     short simulate juan.jim  R       1:20      1 cp39
#           53386211     short simulate juan.jim  R       1:20      1 cp26
#           53386212     short simulate juan.jim  R       1:20      1 cp26
#           53386213     short simulate juan.jim  R       1:20      1 cp26
#           53386214     short simulate juan.jim  R       1:20      1 cp26
#           53386215     short simulate juan.jim  R       1:20      1 cp26
#           53386216     short simulate juan.jim  R       1:20      1 cp40
#           53386217     short simulate juan.jim  R       1:20      1 cp40
#           53386166     short simulate juan.jim  R       1:23      1 cp18
#           53386167     short simulate juan.jim  R       1:23      1 cp18
#           53386168     short simulate juan.jim  R       1:23      1 cp18
#           53386169     short simulate juan.jim  R       1:23      1 cp18
#           53386170     short simulate juan.jim  R       1:23      1 cp18
#           53386171     short simulate juan.jim  R       1:23      1 cp19
#           53386172     short simulate juan.jim  R       1:23      1 cp19
#           53386173     short simulate juan.jim  R       1:23      1 cp19
#           53386165     short simulate juan.jim  R       1:24      1 cp18

# %% [markdown]
# ### Reading the result `.npz` files

# %%
# %%time
cache_file = os.path.join(
    "data", "tmp", f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}_N{n_sim_f}_cache.pkl"
)

if os.path.exists(cache_file):
    print(f"Loading cached results...\n")
    with open(cache_file, "rb") as f:
        (
            a_f, dec_f, lambda_f, lambda_ra_f, lambda_dec_f, ts_dist_f, ts2_dist_f, tsmax_f, tsmax_ra_f, tsmax_dec_f
        ) = pickle.load(f)
else:
    print("Reading and re-agruping data...")
    ra_f, dec_f, lambda_f, lambda_ra_f, lambda_dec_f = [], [], [], [], []
    ts_dist_f, ts2_dist_f, tsmax_f, tsmax_ra_f, tsmax_dec_f = [], [], [], [], []

    for i, amplitude in enumerate(amplitudes): 
        fname_results_f  = f"{source_name}_{type_obs}_E_{e_min.value}_{e_max.value}"
        fname_results_f += f"_N_{n_sim_f}_f_{amplitude}_{'extended' if bool(compute_uls_f) else ''}.npz"
        path_results_f   = os.path.join("data", "results", fname_results_f)
        
        print(f"Loading data... {i/len(amplitudes)*100:.2f}%", end="\r")

        data = np.load(path_results_f)
        _lambda_ra_f_, _lambda_dec_f_ = -data["f_ra"], data["f_dec"]

        # Check if event is inside masked region
        contour_set = plt.contour(
            np.rad2deg(ra_grid), np.rad2deg(dec_grid), np.flip(data_ligo_2d, axis=1), levels=[threshold_maps[0]]
        )
        paths = contour_set.get_paths()
        plt.close()

        is_inside = np.array([
            any(p.contains_point((_lambda_ra_f_[j], _lambda_dec_f_[j])) for p in paths) for j in range(len(_lambda_ra_f_))
        ])
        # is_inside = np.full(len(_lambda_ra_f_), True)
        
        ra_f.append(_lambda_ra_f_[is_inside])
        dec_f.append(_lambda_dec_f_[is_inside])
        lambda_f.append(data["lambda_data"][is_inside])
        lambda_ra_f.append(data["lambda_ra"][is_inside])
        lambda_dec_f.append(data["lambda_dec"][is_inside])
        tsmax_f.append(data["tsmax"][is_inside])
        tsmax_ra_f.append(data["tsmax_ra"][is_inside])
        tsmax_dec_f.append(data["tsmax_dec"][is_inside])

        # This can be commented as loading a lot of maps might crash
        # ts_dist_f.append(data["ts_dist"][is_inside])
        # ts2_dist_f.append(data["ts2_dist"][is_inside])

    # Save backup as a .pkl so we dont read the results again and again
    with open(cache_file, "wb") as f:
        pickle.dump(
            (ra_f, dec_f, lambda_f, lambda_ra_f, lambda_dec_f, ts_dist_f, ts2_dist_f, tsmax_f, tsmax_ra_f, tsmax_dec_f),
            f
        )

# %% [markdown]
# #### Plotting all the distributions

# %%
log_amplitudes

# %%
log_amplitudes = np.log10(amplitudes)
log_edges_inner = (log_amplitudes[1:] + log_amplitudes[:-1]) / 2
amplitude_edges_inner = 10**log_edges_inner

first_edge = 10**(2*log_amplitudes[0] - log_edges_inner[0])
last_edge = 10**(2*log_amplitudes[-1] - log_edges_inner[-1])

amplitude_edges = np.concatenate([[first_edge], amplitude_edges_inner, [last_edge]])

delta_l_bkg = max_l_bkg - min_l_bkg
lambda_bins = np.linspace(min_l_bkg - delta_l_bkg * 0.1, max_l_bkg  +  delta_l_bkg * 1.5, 200)
lambda_bins_ext = np.linspace(min_l_bkg - delta_l_bkg * 0.1, max_l_bkg  +  delta_l_bkg * 1.5, 200)
lambda_bins_c = (lambda_bins[1:] + lambda_bins[:-1]) / 2

lambda_hist_bkg = np.histogram(lambda_bkg, lambda_bins, density=False)[0]
lambda_hist_f   = np.array([np.histogram(l, lambda_bins, density=False)[0] for l in lambda_f])

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 4), gridspec_kw={"height_ratios": [6, 1]}, sharex=True)

pc1 = ax1.pcolormesh(lambda_bins, amplitude_edges, lambda_hist_f, norm=LogNorm(), cmap="plasma")
pc2 = ax2.pcolormesh(lambda_bins, [0, 1], [lambda_hist_bkg], norm=LogNorm(), cmap="viridis")

for ax in [ax1, ax2]:
    ax.set_facecolor("k")
ax1.set_ylim(1e-13, 7e-11); ax1.set_yscale("log"); ax2.set_yticks([])
ax2.set_ylabel(f"BKG"); ax2.set_xlabel("$\\Lambda$"); ax1.set_ylabel("$\\phi_0$ [cm${}^{-2}$s${}^{-1}$ TeV${}^{-1}$]")
ax1.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}"); plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# ## Computing sensitivity + ULs
# First we set the confidence level of the limits selection.
#
# Then we can find the ULs fitting the curves to a sigmoid but usually does not fit very well so we just check where the curve hits the turning point.

# %%
cl = 0.95

# %%
lambda_f_m = np.array([np.percentile(l, 50) for l in lambda_f])

# The fraction of lambdas simulated larger than the data or the BKG of lambda
lambda_f_frac_bkg  = np.array([np.sum(l > lambda_bkg_m) / len(l) for l in lambda_f])
lambda_f_frac_real = np.array([np.sum(l > lambda_real)  / len(l) for l in lambda_f])

# Fitting a sigmoid to the fraction of lambdas
x_bkg, y_bkg = np.log10(amplitudes), lambda_f_frac_bkg
popt_bkg, pcov_bkg   = curve_fit(
    utils.sigmoid, x_bkg, y_bkg, p0=[max(y_bkg), np.median(x_bkg), 1, min(y_bkg)]
)
x_real, y_real = np.log10(amplitudes), lambda_f_frac_real
popt_real, pcov_real = curve_fit(
    utils.sigmoid, x_real, y_real, p0=[max(y_real), np.median(x_real), 1, min(y_real)]
)

# amplitude95_bkg  = 10 ** utils.find_x_at_y(cl, popt_bkg)
# amplitude95_real = 10 ** utils.find_x_at_y(cl, popt_real)

# We check manually where the threshold point is
amplitude95_bkg  = utils.find_amplitude_at_cl(np.log10(amplitudes), lambda_f_frac_bkg, cl=cl)
amplitude95_real = utils.find_amplitude_at_cl(np.log10(amplitudes), lambda_f_frac_real, cl=cl)

idx_f_bkg  = np.abs(amplitudes - amplitude95_bkg).argmin()
idx_f_real = np.abs(amplitudes - amplitude95_real).argmin()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5.4, 3))

ax.plot(amplitudes, lambda_f_frac_bkg,  color="k", label="$\\Lambda>\\Lambda_{bkg}$")
ax.plot(amplitudes, lambda_f_frac_real, color="r", label="$\\Lambda>\\Lambda_{real}$")
# plt.plot(10**x_bkg,  utils.sigmoid(x_bkg, *popt_bkg),  color="k", ls=":")
# plt.plot(10**x_real, utils.sigmoid(x_bkg, *popt_real), color="r", ls=":")

ax.axvline(amplitude95_bkg, color="k", ls="--")
ax.axvline(amplitude95_real, color="r", ls="--")
ax.axhline(cl, ls=":", color="lightgray", zorder=-2, label=f"C.L. = {cl}")
ax.legend(frameon=False)

ax.set_xlabel("$\\phi_0$ [cm${}^{-2}$s${}^{-1}$ TeV${}^{-1}$]")
ax.set_ylabel("Fraction of events")
ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
ax.set_xlim(1e-13, 5e-11)
ax.set_xscale("log")
plt.show()

# %% [markdown]
# # Summary of results:

# %%
pwl_bkg = PowerLawSpectralModel(
    amplitude=amplitude95_bkg * u.Unit("TeV-1 s-1 cm-2"), index=2
)
flux_bkg = pwl_bkg.integral(*energy_edges)
flux_diff_bkg = pwl_bkg.energy_flux(*energy_edges).to(u.erg/(u.s*u.cm**2))
pwl_real = PowerLawSpectralModel(
    amplitude=amplitude95_real * u.Unit("TeV-1 s-1 cm-2"), index=2
)
flux_real = pwl_real.integral(*energy_edges) 
flux_diff_real = pwl_real.energy_flux(*energy_edges).to(u.erg/(u.s*u.cm**2))

print(f"Analysis of {type_obs} data in Energies {energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
print(f"\nSignifcance of observations: {significance:.2f}\u03C3\n")
col_sens, col_ul, final_f_ul = ("33", "32", flux_real) if (significance >= 0.0) else ("32", "31", flux_bkg)
print(f"\033[{col_sens}mSensitivity of observations:\n - phi0 = {amplitude95_bkg:.2e} TeV-1 s-1 cm-2\033[0m")
print(f"\033[{col_sens}m - Flux = {flux_bkg:.2e}\033[0m")
print(f"\033[{col_sens}m - Differential Flux = {flux_diff_bkg:.2e}\033[0m")

print(f"\033[{col_ul}m\nUpperLimits of observations:\n - phi0 = {amplitude95_real:.2e} TeV-1 s-1 cm-2\033[0m")
print(f"\033[{col_ul}m - Flux = {flux_real:.2e}\033[0m")
print(f"\033[{col_ul}m - Differential Flux = {flux_diff_real:.2e}\033[0m")

print(f"\nRelative differences with sky-map ULs:")
print(f" - With Full Map: {(final_f_ul.value-np.nanmax(flux_uls))/np.nanmax(flux_uls)*100:+.1f}%")
print(f" - With 95% region: {(final_f_ul.value-np.nanmax(flux_uls_95))/np.nanmax(flux_uls_95)*100:+.1f}%")

# %% [markdown]
# ### Showing the threshold simulated case

# %%
fig, axt = plt.subplots(1, 1, figsize=(7, 3))

axt.hist(lambda_bkg, lambda_bins, color="royalblue", 
         density=True, histtype="stepfilled", label=f"BKG sim\nN={len(lambda_bkg)}")
axt.hist(lambda_f[idx_f_bkg if significance < 0 else idx_f_real], 
         lambda_bins_ext, color="r", density=True, histtype="step", label=f"Sim of final UL")

axt.text(
    0.85, 0.87, f"p-value={p_value:.2f}\nsignificance={significance:.2f} $\\sigma$",
    ha="center", va="center", transform=axt.transAxes
)
axt.axvline(lambda_real, color="k", ls="--", label=f"Real data\n$\\Lambda=${lambda_real:.2f}")
axt.axvline(lambda_bkg_m, color="darkblue", ls=":", label=f"BKG median\n$\\Lambda=${lambda_bkg_m:.2f}")

axt.legend(frameon=False, loc=4)
axt.set_xlabel("$\\Lambda$"); axt.set_ylabel("Normalized counts")

pwl_sim = PowerLawSpectralModel(
    amplitude=amplitudes[idx_f_bkg if significance < 0 else idx_f_real] * u.Unit("TeV-1 s-1 cm-2"), index=2
)
flux_sim = pwl_sim.integral(*energy_edges)

axt.set_title(f"Sim flux {flux_sim:.2e},   {energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
fig.tight_layout()

plt.show()

# %% [markdown]
# ### Showing the ULs in front of the real distributions

# %%
fig, ax = plt.subplots(figsize=(3, 2))

h = ax.hist(flux_uls, 40, histtype="stepfilled", color="lightgray", label="Total distribution")
ax.hist(flux_uls_95, h[1], histtype="step", color="k", label="ULs in 95%")

if significance >= 0.0:
    col_sens, col_ul = "darkorange", "green"
    lab_sens, lab_ul = "Sensitivity", "Data UL"
    ls_sens,  ls_ul  = "--", "-"
else:
    col_sens, col_ul = "green", "darkorange"
    lab_sens, lab_ul = "Data UL", "Overestimated UL"
    ls_sens,  ls_ul  = "-", "--"

ax.axvline(flux_bkg.value, ls=ls_sens, color=col_sens)
ax.errorbar(flux_bkg.value, np.diff(ax.get_ylim())[0]/2, yerr=0, 
    xerr=flux_bkg.value*0.2, xuplims=True, ls="", color=col_sens, label=lab_sens)

ax.axvline(flux_real.value, ls=ls_ul, color=col_ul)
ax.errorbar(flux_real.value, np.diff(ax.get_ylim())[0]/2, yerr=0, 
    xerr=flux_real.value*0.2, xuplims=True, ls="", color=col_ul, label=lab_ul)
    
ax.set_xlabel("Flux UL [1 / (s cm2)]"); ax.set_ylabel("Normalized counts")
ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
ax.legend(frameon=False, loc=(1.03, 0))

plt.show()

# %% [markdown]
# ### Showing UL distributions in the simulations

# %%
if compute_uls:
    
    fig, ax = plt.subplots(figsize=(5, 3))
    
    ax.hist(ulmax_bkg, 25, density=True, 
            histtype="stepfilled", color="royalblue", label="Maximum UL in 95%", zorder=-5)
    
#     ax.hist(flux_uls, 50, density=True, histtype="step", ls=":", color="k", label="Real Data", zorder=10)
    ax.hist(flux_uls_95, 40, density=True, histtype="step", color="k", label="Real Data 95%", zorder=10)
    
    for data in ul_dist:
        data_95 = np.where(mask_threshold_95, data, np.nan).ravel()
        ax.hist(data_95, 40, density=True, histtype="step", color="0.5", alpha=0.2, zorder=0)
    
    flux_ul = flux_bkg if significance < 0 else flux_real
    ax.axvline(flux_ul.value, ls="-", color="crimson")
    ax.errorbar(flux_ul.value, np.diff(ax.get_ylim())[0]/2, yerr=0, 
        xerr=flux_ul.value*0.4, xuplims=True, ls="", color="crimson", label="Global UL")
    ax.plot([], [], color="gray", ls="-", marker="", 
            label="Simulation\ndistributions 95%")

    
    ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
    
    ax.legend(loc=(1.03, 0), frameon=False)
    ax.set_xlabel("Flux UL [1 / (s cm2)]"); ax.set_ylabel("Normalized counts")
    
    plt.show()

# %%
if compute_uls:
    
    fig, ax = plt.subplots(figsize=(5, 3))
    
    ax.hist(lambda_bkg, 30, density=True, 
            histtype="stepfilled", color="r", label="$\\Lambda$ (max TS')", zorder=-5)
    ts2_masked = np.where(mask_threshold_95, ts2, np.nan).ravel()
    ax.hist(ts2_masked, 30, density=True, histtype="step", color="k", label="Real Data", zorder=10)
    for data in ts2_dist:
        data = np.where(mask_threshold_95, data, np.nan).ravel()
        ax.hist(data, 30, density=True, histtype="step", color="0.5", alpha=0.2, zorder=0)
    
    ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
    ax.plot([], [], color="0.8", label="Simulated data")
    
    plt.legend(loc=(1.03, 0), frameon=False)
    ax.set_xlabel("TS'"); ax.set_ylabel("Normalized counts")
    ax.set_title(f"{energy_edges[0]:.2f}-{energy_edges[1]:.2f}")
    plt.show()
